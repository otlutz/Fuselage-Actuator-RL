# %% [markdown]
# # Table 4 Row 1 (Verify benchmark forces in the environment)

# %% [markdown]
# Load forces calculated from Du benchmark method

# %%
import pandas as pd

df = pd.read_csv('./Data/ADMM_Benchmark_Forces.csv', header=None)
forces = df.values.T
print(forces[0])
# Out:
# [-155.6882056     0.          120.4716266   123.1237685     0.
#  -133.3444861     0.          283.5795504    85.86173852    0.
#  -194.9797063     0.            0.            0.            0.
#    98.67796165   56.27118196    3.89644975]

# %% [markdown]
# Apply forces in v22 environment

# %%
import numpy as np
import os
from os import path
import gym
from AssemblyGym.envs import FuselageActuators


env_id = "FuselageActuators-v22"

# Select files
file2 ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
folder ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Test/'
files = os.listdir('./AssemblyGym/envs/FuselageActuators/AnsysFiles/Test/')


errors = []
maxDevs = []
meanForces = []
maxForces = []
# Loop over test samples
for i in range(19):
    print('*' * 30, f'Test sample {i+1}', '*' * 30)
    file1 = path.join(folder, files[i])
    env = gym.make(env_id, n_actuators=10, mode="File", file1=file1, file2=file2, record=False, seed=0, port=50056)
    cur_state = env.reset()
    done, r_tot = False, 0
    action = -forces[i]/1000
    next_state, reward, done, info = env.step(action)
    print("Reward:", reward)
    print("Final Error:", info["Error"])
    errors.append(info["Error"])
    maxDevs.append(info["maxDev"])
    meanForces.append(np.mean(forces))
    maxForces.append(np.max(forces))
    print('')
    env.close()   

print('*' * 30, 'Summary of Results', '*' * 30)
print("Mean RMSD = ", np.mean(errors))
print("Mean MD = ", np.mean(maxDevs))
print("Mean MF = ", np.mean(maxForces))

print("Max RMSD = ", np.max(errors))
print("Max MD = ", np.max(maxDevs))
print("Max MF = ", np.max(maxForces))
# Out:
# ****************************** Test sample 1 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Exit Ansys and try to reconnect
# Remote exit
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 1
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9791273301370229
# Final Error: 0.006240796302079029
#
# ****************************** Test sample 2 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.968859527115289
# Final Error: 0.004948836553818123
#
# ****************************** Test sample 3 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9703862249766817
# Final Error: 0.016666639761902708
#
# ****************************** Test sample 4 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9660088841548226
# Final Error: 0.01959027065020436
#
# ****************************** Test sample 5 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9775509933816292
# Final Error: 0.009123296604706944
#
# ****************************** Test sample 6 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9774979524571551
# Final Error: 0.006270913788001534
#
# ****************************** Test sample 7 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9911156522431417
# Final Error: 0.00694222178707848
#
# ****************************** Test sample 8 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Exit Ansys and try to reconnect
# Remote exit
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 1
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9700509299224956
# Final Error: 0.014448914023434845
#
# ****************************** Test sample 9 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9720702060194452
# Final Error: 0.017818641070055045
#
# ****************************** Test sample 10 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9729175423164078
# Final Error: 0.017497282039584977
#
# ****************************** Test sample 11 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 2
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 3
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9712137251262457
# Final Error: 0.004330688342756402
#
# ****************************** Test sample 12 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9853883855003739
# Final Error: 0.0035104455001933104
#
# ****************************** Test sample 13 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 2
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 3
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9710333152435575
# Final Error: 0.018082177173247775
#
# ****************************** Test sample 14 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9762920924621443
# Final Error: 0.005882009697550888
#
# ****************************** Test sample 15 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9721745273473817
# Final Error: 0.007074835291514029
#
# ****************************** Test sample 16 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9884268069204429
# Final Error: 0.010438959372093558
#
# ****************************** Test sample 17 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9754061219487649
# Final Error: 0.015607657881543776
#
# ****************************** Test sample 18 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 2
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9736403921281742
# Final Error: 0.024337762854066206
#
# ****************************** Test sample 19 ******************************
# Exit Ansys and try to reconnect
# No active Ansys process found. Wait and try to reconnect
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 1
# Reconnect failed - remote exit again
# Wait and try to reconnect again - attempt 2
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.61.2
#
# Running on 4 processors
# Sucessfully reconnected to Ansys on attempt 3
# Try running again
# Simulation setup complete
# Applied forces
# Solve finished
# Results ready
# Reward: 0.9496468640456224
# Final Error: 0.003592030052378393
#
# ****************************** Summary of Results ******************************
# Mean RMSD =  0.011179177828747914
# Mean MD =  0.024078412633001166
# Mean MF =  289.53654900000004
# Max RMSD =  0.024337762854066206
# Max MD =  0.04903018238336659
# Max MF =  289.536549

# %% [markdown]
# ****************************** Summary of Results ******************************
# **********************************************************
#
# Mean RMSD =  0.011179177828747914
#
# Mean MD =  0.024078412633001166
#
# Mean MF =  289.53654900000004
#
# **********************************************************
#
# Max RMSD =  0.024337762854066206
#
# Max MD =  0.04903018238336659
#
# Max MF =  289.536549

# %% [markdown]
# # Table 4 Row 2 (Compare against forces from RL agent)

# %% [markdown]
# ### Single shot adjustment

# %%
import os
from os import path
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import gym
import torch
from torch import nn
import torch.nn.functional as F
from torch.distributions.normal import Normal

from AssemblyGym.envs import FuselageActuators

def make_env(env_id, seed, idx, n_actions, file1, file2, record):
    def thunk():
        env = gym.make(env_id, n_actuators=n_actions, mode="File", file1=file1, file2=file2, record=record, seed=seed, port=50056+idx)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        return env

    return thunk

def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer


class Agent(nn.Module):
    def __init__(self, envs):
        super().__init__()
        self.critic = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.observation_space.shape).prod(), 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 1), std=1.0),
        )
        # layers for self.actor_mean
        self.fc1 = layer_init(nn.Linear(np.array(envs.observation_space.shape).prod(), 64))
        self.fc2 = layer_init(nn.Linear(64, 64))
        self.fc3 = layer_init(nn.Linear(64, np.prod(envs.action_space.shape)), std=0.01)
        
        self.actor_logstd = nn.Parameter(1*torch.ones(1, np.prod(envs.action_space.shape)), requires_grad=False)  # initial action_std = exp(actor_logstd)

    def get_value(self, obs):
        return self.critic(obs)

    def get_action_and_value(self, obs, action=None, scaleStd=1):
        # Start with standard MLP
        x = torch.tanh(self.fc1(obs))
        x = torch.tanh(self.fc2(x))
        action_mean = torch.tanh(self.fc3(x))
        # Build action distribution
        action_logstd = self.actor_logstd#.expand_as(action_mean)
        action_std = torch.exp(action_logstd)*scaleStd
        probs = Normal(action_mean, action_std)
        if action is None:
            action = probs.sample()
        if action == "deterministic":
            action = action_mean
        return action, probs.log_prob(action).sum(1), probs.entropy().sum(1), self.critic(obs)

# Make dummy environment to initialize agent against
env_name = "FuselageActuators-v22"
file2 ='./AssemblyGym/AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
file1 ='./AssemblyGym/AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
# envs = gym.vector.SyncVectorEnv(
#     [make_env(env_name, 0 + i, i, 10, file1, file2, False) for i in range(1)]
# )
envs = gym.make(env_name, n_actuators=10, mode="File", file1=file1, file2=file2, record=False, seed=0, port=50056)

# Create agent
device = torch.device("cpu")
agent = Agent(envs).to(device)
agent.load_state_dict(torch.load(
            "./Agents/agent_32767872steps.pt", map_location=device))
envs.close()

# Initialze variables
initErrors = []
finalErrors = []
maxDevs = []
maxForces = []
rewards = []

# Select files
file2 ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
folder ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Test/'
files = os.listdir(folder)

# Loop over all files
for f in files[:-1]:
    file1 = path.join(folder, f)
    dp = file1[-8:-4] # Design point

    # Make the environment
    # env_name = "FuselageActuators-v22"
    # envs = gym.vector.SyncVectorEnv(
    #     [make_env(env_name, 0 + i, i, 10, file1, file2, False) for i in range(1)]
    # )
    print('*' * 30, f'File: {f}', '*' * 30)
    envs = gym.make(env_name, n_actuators=10, mode="File", file1=file1, file2=file2, record=False, seed=0, port=50056)

    
    # Perform test and track error
    obs = torch.Tensor(envs.reset()).to(device)
    #initErrors.append(envs.error_initial)
    episodeReward = 0
    # done=False
    # while not done:
    with torch.no_grad():
        action, logprob, _, value = agent.get_action_and_value(obs, action = "deterministic")
    obs, reward, done, info = envs.step(action.cpu().numpy())
    obs = torch.Tensor(obs).to(device)
    episodeReward += reward
    print("Reward:", episodeReward)
    print("Final Error:", info["Error"])
    initErrors.append(info["initError"])
    finalErrors.append(info["Error"])
    maxDevs.append(info["maxDev"])
    maxForces.append(np.max(np.abs(info["Forces"])))
    rewards.append(episodeReward)
    # n_actuators.append(np.count_nonzero(envs.forces))

    envs.close()

print("**********************************************************")
print("Initial error (mean) = %.3f" %np.mean(initErrors))
print("Initial error (median) = %.3f" %np.median(initErrors))
print("Initial error (stdev) = %.3f" %np.std(initErrors))
print("Initial error (max) = %.3f" %np.max(initErrors))
print("**********************************************************")
print("Final error (mean) = %.3f" %np.mean(finalErrors))
print("Final error (median) = %.3f" %np.median(finalErrors))
print("Final error (stdev) = %.3f" %np.std(finalErrors))
print("Final error (max) = %.3f" %np.max(finalErrors))
print("**********************************************************")
print("Max Deviation (mean) = %.3f" %np.mean(maxDevs))
print("Max Deviation (median) = %.3f" %np.median(maxDevs))
print("Max Deviation (stdev) = %.3f" %np.std(maxDevs))
print("Max Deviation (max) = %.3f" %np.max(maxDevs))
print("**********************************************************")
print("Max Force (mean) = %.3f" %np.mean(maxForces))
print("Max Force (median) = %.3f" %np.median(maxForces))
print("Max Force (stdev) = %.3f" %np.std(maxForces))
print("Max Force (max) = %.3f" %np.max(maxForces))
print("**********************************************************")
print("Episode Rewards (mean) = %.3f" %np.mean(rewards))
print("Episode Rewards (median) = %.3f" %np.median(rewards))
print("Episode Rewards (stdev) = %.3f" %np.std(rewards))
# Out:
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\scooby\knowledge.py:14: DeprecationWarning: The distutils.sysconfig module is deprecated, use sysconfig instead
#   import distutils.sysconfig as sysconfig
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\gym\core.py:329: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\gym\wrappers\step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# ****************************** File: SolutionInputDP41.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\gym\utils\passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\gym\utils\passive_env_checker.py:190: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `return_info` to return information from the environment resetting.
#   logger.warn(
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\gym\utils\passive_env_checker.py:195: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\gym\utils\passive_env_checker.py:227: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# Reward: 0.9682654089509896
# Final Error: 0.009488442052060824
# ****************************** File: SolutionInputDP42.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9377830113594768
# Final Error: 0.009887509055903842
# ****************************** File: SolutionInputDP43.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.97484035961647
# Final Error: 0.014159851706887444
# ****************************** File: SolutionInputDP44.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9849069648747188
# Final Error: 0.00869864479836567
# ****************************** File: SolutionInputDP45.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9652412930737209
# Final Error: 0.014125969949379426
# ****************************** File: SolutionInputDP46.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9744097308880946
# Final Error: 0.007131545300798386
# ****************************** File: SolutionInputDP47.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9752918882525821
# Final Error: 0.01930689752188985
# ****************************** File: SolutionInputDP48.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9834097977563138
# Final Error: 0.008003934854407087
# ****************************** File: SolutionInputDP49.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9853258303366667
# Final Error: 0.009361822089130698
# ****************************** File: SolutionInputDP50.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9830776693426054
# Final Error: 0.010933084276872554
# ****************************** File: SolutionInputDP51.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9501228543436643
# Final Error: 0.007503658400093828
# ****************************** File: SolutionInputDP52.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9520166966211467
# Final Error: 0.01152800543944104
# ****************************** File: SolutionInputDP53.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9846707620331266
# Final Error: 0.009569130854238748
# ****************************** File: SolutionInputDP54.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9577190515900025
# Final Error: 0.010490042116629097
# ****************************** File: SolutionInputDP55.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9562575845261903
# Final Error: 0.011121837483003494
# ****************************** File: SolutionInputDP56.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9688699528842001
# Final Error: 0.028079138994683648
# ****************************** File: SolutionInputDP57.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9876138043454961
# Final Error: 0.007860472586983969
# ****************************** File: SolutionInputDP58.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# Product:             Ansys Mechanical Enterprise Academic Teaching
# MAPDL Version:       22.1
# ansys.mapdl Version: 0.64.0
#
# Running on 4 processors
# Reward: 0.9824418782941549
# Final Error: 0.016211371744131124
# ****************************** File: SolutionInputDP59.inp ******************************
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1072: DeprecationWarning: invalid escape sequence '\d'
#   and re.search("ansys\d\d\d", os.path.basename(os.path.normpath(exe_loc)))
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1249: DeprecationWarning: invalid escape sequence '\-'
#   """Start MAPDL locally.
# ---------------------------------------------------------------------------
# MapdlConnectionError                      Traceback (most recent call last)
# File c:\Users\TL\Projects\Fuselage Actuator Reinforcement Learning\Fuselage-Actuator-RL\AssemblyGym\envs\FuselageActuators\FuselageActuators_env_v22.py:486, in FuselageActuatorsEnv._launch_ansys(self)
#     485 n_cpu = psutil.cpu_count(logical=False)
# --> 486 self.mapdl = launch_mapdl(loglevel='ERROR', verbose=False, nproc=n_cpu, cleanup_on_exit=True, override=True)
#     487 print(self.mapdl)
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1872, in launch_mapdl(exec_file, run_location, jobname, nproc, ram, mode, override, loglevel, additional_switches, start_timeout, port, cleanup_on_exit, start_instance, ip, clear_on_connect, log_apdl, remove_temp_files, remove_temp_dir_on_exit, verbose_mapdl, license_server_check, license_type, print_com, add_env_vars, replace_env_vars, version, **kwargs)
#    1870         lic_check.check()
# -> 1872     raise exception
#    1874 # Stopping license checker
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1851, in launch_mapdl(exec_file, run_location, jobname, nproc, ram, mode, override, loglevel, additional_switches, start_timeout, port, cleanup_on_exit, start_instance, ip, clear_on_connect, log_apdl, remove_temp_files, remove_temp_dir_on_exit, verbose_mapdl, license_server_check, license_type, print_com, add_env_vars, replace_env_vars, version, **kwargs)
#    1843 port, actual_run_location, process = launch_grpc(
#    1844     port=port,
#    1845     ip=ip,
#    (...)
#    1849     **start_parm,
#    1850 )
# -> 1851 mapdl = MapdlGrpc(
#    1852     ip=ip,
#    1853     port=port,
#    1854     cleanup_on_exit=cleanup_on_exit,
#    1855     loglevel=loglevel,
#    1856     set_no_abort=set_no_abort,
#    1857     remove_temp_dir_on_exit=remove_temp_dir_on_exit,
#    1858     log_apdl=log_apdl,
#    1859     process=process,
#    1860     **start_parm,
#    1861 )
#    1862 if run_location is None:
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:386, in MapdlGrpc.__init__(self, ip, port, timeout, loglevel, log_file, cleanup_on_exit, log_apdl, set_no_abort, remove_temp_files, remove_temp_dir_on_exit, print_com, channel, remote_instance, **start_parm)
#     385     self._post_mortem_checks()
# --> 386     raise err  # Raise original error if we couldn't catch it in post-mortem analysis
#     387 else:
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:383, in MapdlGrpc.__init__(self, ip, port, timeout, loglevel, log_file, cleanup_on_exit, log_apdl, set_no_abort, remove_temp_files, remove_temp_dir_on_exit, print_com, channel, remote_instance, **start_parm)
#     382 try:
# --> 383     self._multi_connect(timeout=timeout, set_no_abort=set_no_abort)
#     384 except MapdlConnectionError as err:
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:454, in MapdlGrpc._multi_connect(self, n_attempts, timeout, set_no_abort)
#     453 if not connected:
# --> 454     raise MapdlConnectionError(
#     455         f"Unable to connect to MAPDL gRPC instance at {self._channel_str}."
#     456     )
#     457 else:
#
# MapdlConnectionError: Unable to connect to MAPDL gRPC instance at 127.0.0.1:50052.
#
# During handling of the above exception, another exception occurred:
#
# MapdlConnectionError                      Traceback (most recent call last)
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:383, in MapdlGrpc.__init__(self, ip, port, timeout, loglevel, log_file, cleanup_on_exit, log_apdl, set_no_abort, remove_temp_files, remove_temp_dir_on_exit, print_com, channel, remote_instance, **start_parm)
#     382 try:
# --> 383     self._multi_connect(timeout=timeout, set_no_abort=set_no_abort)
#     384 except MapdlConnectionError as err:
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:454, in MapdlGrpc._multi_connect(self, n_attempts, timeout, set_no_abort)
#     453 if not connected:
# --> 454     raise MapdlConnectionError(
#     455         f"Unable to connect to MAPDL gRPC instance at {self._channel_str}."
#     456     )
#     457 else:
#
# MapdlConnectionError: Unable to connect to MAPDL gRPC instance at 127.0.0.1:50059.
#
# During handling of the above exception, another exception occurred:
#
# MapdlConnectionError                      Traceback (most recent call last)
# c:\Users\TL\Projects\Fuselage Actuator Reinforcement Learning\Fuselage-Actuator-RL\BenchmarkCheck.ipynb Cell 9 in <cell line: 92>()
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/Fuselage-Actuator-RL/BenchmarkCheck.ipynb#X11sZmlsZQ%3D%3D?line=95'>96</a> # Make the environment
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/Fuselage-Actuator-RL/BenchmarkCheck.ipynb#X11sZmlsZQ%3D%3D?line=96'>97</a> # env_name = "FuselageActuators-v22"
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/Fuselage-Actuator-RL/BenchmarkCheck.ipynb#X11sZmlsZQ%3D%3D?line=97'>98</a> # envs = gym.vector.SyncVectorEnv(
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/Fuselage-Actuator-RL/BenchmarkCheck.ipynb#X11sZmlsZQ%3D%3D?line=98'>99</a> #     [make_env(env_name, 0 + i, i, 10, file1, file2, False) for i in range(1)]
#     <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/Fuselage-Actuator-RL/BenchmarkCheck.ipynb#X11sZmlsZQ%3D%3D?line=99'>100</a> # )
#     <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/Fuselage-Actuator-RL/BenchmarkCheck.ipynb#X11sZmlsZQ%3D%3D?line=100'>101</a> print('*' * 30, f'File: {f}', '*' * 30)
# --> <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/Fuselage-Actuator-RL/BenchmarkCheck.ipynb#X11sZmlsZQ%3D%3D?line=101'>102</a> envs = gym.make(env_name, n_actuators=10, mode="File", file1=file1, file2=file2, record=False, seed=0, port=50056)
#     <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/Fuselage-Actuator-RL/BenchmarkCheck.ipynb#X11sZmlsZQ%3D%3D?line=104'>105</a> # Perform test and track error
#     <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/Fuselage-Actuator-RL/BenchmarkCheck.ipynb#X11sZmlsZQ%3D%3D?line=105'>106</a> obs = torch.Tensor(envs.reset()).to(device)
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\gym\envs\registration.py:649, in make(id, max_episode_steps, autoreset, new_step_api, disable_env_checker, **kwargs)
#     644         raise error.Error(
#     645             f"Invalid render_mode provided: {mode}. Valid render_modes: None, {', '.join(render_modes)}"
#     646         )
#     648 try:
# --> 649     env = env_creator(**_kwargs)
#     650 except TypeError as e:
#     651     if (
#     652         str(e).find("got an unexpected keyword argument 'render_mode'") >= 0
#     653         and apply_human_rendering
#     654     ):
#
# File c:\Users\TL\Projects\Fuselage Actuator Reinforcement Learning\Fuselage-Actuator-RL\AssemblyGym\envs\FuselageActuators\FuselageActuators_env_v22.py:76, in FuselageActuatorsEnv.__init__(self, render_mode, n_actuators, mode, port, file1, file2, record, seed)
#      73 if self.mode != 'Surrogate':
#      74     # Check if MAPDL server is active, and start it if it's not
#      75     if not self._monitor_process('ansys'):
# ---> 76         self._launch_ansys()
#      77 elif self.mode == 'Surrogate':
#      78     self.surrogate = load(path.join(path.dirname(__file__), 'Surrogates', 'surrogate_likeDu_v22.joblib') )
#
# File c:\Users\TL\Projects\Fuselage Actuator Reinforcement Learning\Fuselage-Actuator-RL\AssemblyGym\envs\FuselageActuators\FuselageActuators_env_v22.py:491, in FuselageActuatorsEnv._launch_ansys(self)
#     489 except:
#     490     n_cpu=min(4, n_cpu) #license sometimes won't let me use more than 4 processors?
# --> 491     self.mapdl = launch_mapdl(loglevel='ERROR', verbose=False, port=self.port, nproc=n_cpu, cleanup_on_exit=True, override=True)
#     492     print(self.mapdl)
#     493     print("Running on", n_cpu, "processors")
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1872, in launch_mapdl(exec_file, run_location, jobname, nproc, ram, mode, override, loglevel, additional_switches, start_timeout, port, cleanup_on_exit, start_instance, ip, clear_on_connect, log_apdl, remove_temp_files, remove_temp_dir_on_exit, verbose_mapdl, license_server_check, license_type, print_com, add_env_vars, replace_env_vars, version, **kwargs)
#    1869         LOG.debug("Checking license server.")
#    1870         lic_check.check()
# -> 1872     raise exception
#    1874 # Stopping license checker
#    1875 if license_server_check:
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1851, in launch_mapdl(exec_file, run_location, jobname, nproc, ram, mode, override, loglevel, additional_switches, start_timeout, port, cleanup_on_exit, start_instance, ip, clear_on_connect, log_apdl, remove_temp_files, remove_temp_dir_on_exit, verbose_mapdl, license_server_check, license_type, print_com, add_env_vars, replace_env_vars, version, **kwargs)
#    1842 elif mode == "grpc":
#    1843     port, actual_run_location, process = launch_grpc(
#    1844         port=port,
#    1845         ip=ip,
#    (...)
#    1849         **start_parm,
#    1850     )
# -> 1851     mapdl = MapdlGrpc(
#    1852         ip=ip,
#    1853         port=port,
#    1854         cleanup_on_exit=cleanup_on_exit,
#    1855         loglevel=loglevel,
#    1856         set_no_abort=set_no_abort,
#    1857         remove_temp_dir_on_exit=remove_temp_dir_on_exit,
#    1858         log_apdl=log_apdl,
#    1859         process=process,
#    1860         **start_parm,
#    1861     )
#    1862     if run_location is None:
#    1863         mapdl._path = actual_run_location
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:385, in MapdlGrpc.__init__(self, ip, port, timeout, loglevel, log_file, cleanup_on_exit, log_apdl, set_no_abort, remove_temp_files, remove_temp_dir_on_exit, print_com, channel, remote_instance, **start_parm)
#     383     self._multi_connect(timeout=timeout, set_no_abort=set_no_abort)
#     384 except MapdlConnectionError as err:
# --> 385     self._post_mortem_checks()
#     386     raise err  # Raise original error if we couldn't catch it in post-mortem analysis
#     387 else:
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:476, in MapdlGrpc._post_mortem_checks(self)
#     473 # check the stdout for any errors
#     474 self._read_stds()
# --> 476 self._check_stds()
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:507, in MapdlGrpc._check_stds(self, stdout, stderr)
#     505     self._log.debug("MAPDL exited without stdout.")
#     506 else:
# --> 507     self._parse_stdout()
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:531, in MapdlGrpc._parse_stdout(self, stdout)
#     529 # Custom errors
#     530 self._custom_stds_errors(errs)
# --> 531 raise MapdlConnectionError(errs)
#
# MapdlConnectionError: ---- error analysis -----
#
# ---- error analysis -----

# %% [markdown]
# Expected Output
# **********************************************************
# Initial error (mean) = 0.467
#
# Initial error (median) = 0.482
#
# Initial error (stdev) = 0.251
#
# Initial error (max) = 0.923
# **********************************************************
# Final error (mean) = 0.012
#
# Final error (median) = 0.010
#
# Final error (stdev) = 0.006
#
# Final error (max) = 0.028
# **********************************************************
# Max Deviation (mean) = 0.037
#
# Max Deviation (median) = 0.036
#
# Max Deviation (stdev) = 0.013
#
# Max Deviation (max) = 0.076
# **********************************************************
# Max Force (mean) = 42.936
#
# Max Force (median) = 8.154
#
# Max Force (stdev) = 56.856
#
# Max Force (max) = 268.755
# **********************************************************
# Episode Rewards (mean) = 0.965
#
# Episode Rewards (median) = 0.969
#
# Episode Rewards (stdev) = 0.025

# %% [markdown]
# ### Multiple refinements

# %%
import os
from os import path
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import gym
import torch
from torch import nn
import torch.nn.functional as F
from torch.distributions.normal import Normal

from AssemblyGym.envs import FuselageActuators

def make_env(env_id, seed, idx, n_actions, file1, file2, record):
    env = gym.make(env_id, n_actuators=n_actions, mode="File", file1=file1, file2=file2, record=record, seed=seed, port=50056+idx)
    #env = gym.wrappers.RecordEpisodeStatistics(env)
    return env


def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer


class Agent(nn.Module):
    def __init__(self, envs):
        super().__init__()
        self.critic = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.observation_space.shape).prod(), 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 1), std=1.0),
        )
        # layers for self.actor_mean
        self.fc1 = layer_init(nn.Linear(np.array(envs.observation_space.shape).prod(), 64))
        self.fc2 = layer_init(nn.Linear(64, 64))
        self.fc3 = layer_init(nn.Linear(64, np.prod(envs.action_space.shape)), std=0.01)
        
        self.actor_logstd = nn.Parameter(1*torch.ones(1, np.prod(envs.action_space.shape)), requires_grad=False)  # initial action_std = exp(actor_logstd)

    def get_value(self, obs):
        return self.critic(obs)

    def get_action_and_value(self, obs, action=None, scaleStd=1):
        # Start with standard MLP
        x = torch.tanh(self.fc1(obs))
        x = torch.tanh(self.fc2(x))
        action_mean = torch.tanh(self.fc3(x))
        # Build action distribution
        action_logstd = self.actor_logstd#.expand_as(action_mean)
        action_std = torch.exp(action_logstd)*scaleStd
        probs = Normal(action_mean, action_std)
        if action is None:
            action = probs.sample()
        if action == "deterministic":
            action = action_mean
        return action, probs.log_prob(action).sum(1), probs.entropy().sum(1), self.critic(obs)

# Make the environment
env_name = "FuselageActuators-v22"
file2 ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
file1 ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
# envs = gym.vector.SyncVectorEnv(
#     [make_env(env_name, 0 + i, i, 10, file1, file2, False) for i in range(1)]
# )

envs = make_env(env_name, 0, 0, 10, file1, file2, False)

# Create agent
device = torch.device("cpu")
agent = Agent(envs).to(device)
agent.load_state_dict(torch.load(
            "./Agents/agent_32767872steps.pt", map_location=device))

# Initialze variables
initErrors = []
finalErrors = []
maxDevs = []
maxForces = []
rewards = []
bestForces = []

# Select files
file2 ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
folder ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Test/'
files = os.listdir(folder)

# Loop over all files
for f in files[:-1]:
    file1 = path.join(folder, f)
    dp = file1[-8:-4] # Design point

    # Make the environment
    # env_name = "FuselageActuators-v22"
    # envs = gym.vector.SyncVectorEnv(
    #     [make_env(env_name, 0 + i, i, 10, file1, file2, False) for i in range(1)]
    # )
    print('*' * 30, f'File: {f}', '*' * 30)
    envs = make_env(env_name, 0, 0, 10, file1, file2, False)

    # Perform test and track error
    obs = torch.Tensor(envs.reset()).to(device)
    # initErrors.append(envs.error_initial)
    episodeReward = 0
    minError=10
    
    for j in range(10):
        with torch.no_grad():
            action, logprob, _, value = agent.get_action_and_value(obs, action = "deterministic")
        obs, reward, done, info = envs.step(action.cpu().numpy())
        obs = torch.Tensor(obs).to(device)
        episodeReward += reward
        # print("Intermediate Reward:", reward)
        print("Intermediate Error:", info["Error"])
        if info["Error"]<minError:
            minError= info["Error"]
            maxDev = info["maxDev"]
            maxForce = np.max(np.abs(info["Forces"]))
            bestForce = info["Forces"]
    print('_'*30)
    print("Best Error:", minError)
    initErrors.append(info["initError"])
    finalErrors.append(minError)
    maxForces.append(maxForce)
    maxDevs.append(maxDev)
    rewards.append(episodeReward)
    bestForces.append(bestForce)

    envs.close()

print("**********************************************************")
print("Initial error (mean) = %.4f" %np.mean(initErrors))
print("Initial error (median) = %.4f" %np.median(initErrors))
print("Initial error (stdev) = %.4f" %np.std(initErrors))
print("Initial error (max) = %.4f" %np.max(initErrors))
print("**********************************************************")
print("Final error (mean) = %.4f" %np.mean(finalErrors))
print("Final error (median) = %.4f" %np.median(finalErrors))
print("Final error (stdev) = %.4f" %np.std(finalErrors))
print("Final error (max) = %.4f" %np.max(finalErrors))
print("**********************************************************")
print("Max Deviation (mean) = %.4f" %np.mean(maxDevs))
# Intermediate Error: 0.010251259306539995
# Intermediate Error: 0.01104313543143843
# Intermediate Error: 0.011796118761560054
# Intermediate Error: 0.012558651990068058
# Intermediate Error: 0.013327627087487925
# Intermediate Error: 0.01410142832210758
# Intermediate Error: 0.014878555101937049
# Intermediate Error: 0.015657850817749466
# ______________________________
# Best Error: 0.00939649029893844
# **********************************************************
# Initial error (mean) = 0.4673
# Initial error (median) = 0.4824
# Initial error (stdev) = 0.2508
# Initial error (max) = 0.9233
# **********************************************************
# Final error (mean) = 0.0099
# Final error (median) = 0.0094
# Final error (stdev) = 0.0028
# Final error (max) = 0.0162
# **********************************************************
# Max Deviation (mean) = 0.0331
# Max Deviation (median) = 0.0338
# Max Deviation (stdev) = 0.0077
# Max Deviation (max) = 0.0465
# **********************************************************
# Max Force (mean) = 274.0799
# Max Force (median) = 255.0113
# Max Force (stdev) = 96.0210
# Max Force (max) = 476.3623
# **********************************************************
# Best Forces: [array([   2.4260173,    0.       , -195.67352  , -144.6019   ,
#          66.377754 ,    0.       ,   -0.7945793,    0.       ,
#           0.       ,    0.       ,    0.       ,    0.       ,
#           0.       ,   11.904432 ,   48.80049  , -277.3658   ,
#         247.98181  , -196.37773  ], dtype=float32), array([  42.93125 ,  199.52354 ,  -26.117891,  -55.79798 ,   91.87922 ,
#           0.      ,    0.      ,    0.      ,    0.      ,    0.      ,
#           0.      ,    0.      ,    0.      ,  -29.72947 ,  -34.955605,
#        -293.1178  ,  476.36227 ,  -12.743597], dtype=float32), array([ -85.06643 ,  114.243454,  172.98627 , -369.63937 ,  375.6508  ,
#           0.      ,    0.      ,    0.      ,    0.      ,    0.      ,
#           0.      ,    0.      ,    0.      ,  -56.069016, -351.73724 ,
#        -172.37708 ,   14.872742,  240.64055 ], dtype=float32), array([ 158.70303  ,    0.       ,  -23.222015 ,  118.60626  ,
#         184.64943  ,    0.       ,   -1.0053397,    0.       ,
#           0.       ,    0.       ,    0.       ,    0.       ,
#           0.       ,    8.635729 ,  107.156204 , -624.9568   ,
#         762.82056  , -104.233826 ], dtype=float32), array([  35.481216,   78.53144 , -101.07145 , -277.89914 ,   42.31276 ,
#           0.      ,    0.      ,    0.      ,    0.      ,    0.      ,
#           0.      ,    0.      ,    0.      ,  111.6241  , -101.18796 ,
#        -201.48267 ,  -18.245209, -102.59672 ], dtype=float32), array([-113.17535  ,   34.078922 ,   23.579739 , -258.09518  ,
#         304.16077  ,    0.       ,    0.       ,    0.       ,
#           0.       ,    0.       ,    0.       ,    0.       ,
#           0.       ,  142.27667  ,    3.7591171, -145.66666  ,
#         -52.25402  , -109.12863  ], dtype=float32), array([ 175.96501, -165.92242,  249.58182, -676.36615,  227.10231,
#           0.     ,    0.     ,    0.     ,    0.     ,    0.     ,
#           0.     ,    0.     ,    0.     ,  420.24548, -392.8469 ,
#         413.16824, -454.0486 ,  375.8904 ], dtype=float32), array([ 121.84607  ,    0.       , -161.89484  ,  122.58459  ,
#         154.95767  ,    0.       ,   -0.8608674,    0.       ,
#           0.       ,    0.       ,    0.       ,    0.       ,
# Initial error (median) = 0.4824
# Initial error (stdev) = 0.2508
# Initial error (max) = 0.9233
# **********************************************************
# Final error (mean) = 0.0099
# Final error (median) = 0.0094
# Final error (stdev) = 0.0028
# Final error (max) = 0.0162
# **********************************************************
# Max Deviation (mean) = 0.0331
# Max Deviation (median) = 0.0338
# Max Deviation (stdev) = 0.0077
# Max Deviation (max) = 0.0465
# **********************************************************
# Max Force (mean) = 274.0799
# Max Force (median) = 255.0113
# Max Force (stdev) = 96.0210
# Max Force (max) = 476.3623
# **********************************************************

# %% [markdown]
# ### Multiple refinements (test)

# %%
import os
from os import path
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import gym
import torch
from torch import nn
import torch.nn.functional as F
from torch.distributions.normal import Normal

from AssemblyGym.envs import FuselageActuators

def make_env(env_id, seed, idx, n_actions, file1, file2, record):
    env = gym.make(env_id, n_actuators=n_actions, mode="Test", record=record, seed=seed)
    #env = gym.wrappers.RecordEpisodeStatistics(env)
    return env


def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer


class Agent(nn.Module):
    def __init__(self, envs):
        super().__init__()
        self.critic = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.observation_space.shape).prod(), 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 1), std=1.0),
        )
        # layers for self.actor_mean
        self.fc1 = layer_init(nn.Linear(np.array(envs.observation_space.shape).prod(), 64))
        self.fc2 = layer_init(nn.Linear(64, 64))
        self.fc3 = layer_init(nn.Linear(64, np.prod(envs.action_space.shape)), std=0.01)
        
        self.actor_logstd = nn.Parameter(-5*torch.ones(1, np.prod(envs.action_space.shape)), requires_grad=False)  # initial action_std = exp(actor_logstd)

    def get_value(self, obs):
        return self.critic(obs)

    def get_action_and_value(self, obs, action=None, scaleStd=1):
        # Start with standard MLP
        x = torch.tanh(self.fc1(obs))
        x = torch.tanh(self.fc2(x))
        action_mean = torch.tanh(self.fc3(x))
        # Build action distribution
        action_logstd = self.actor_logstd#.expand_as(action_mean)
        action_std = torch.exp(action_logstd)*scaleStd
        probs = Normal(action_mean, action_std)
        if action is None:
            action = probs.sample()
        if action == "deterministic":
            action = action_mean
        return action, probs.log_prob(action).sum(1), probs.entropy().sum(1), self.critic(obs)

# Make the environment
env_name = "FuselageActuators-v22"
file2 ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
file1 ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
# envs = gym.vector.SyncVectorEnv(
#     [make_env(env_name, 0 + i, i, 10, file1, file2, False) for i in range(1)]
# )

envs = make_env(env_name, 0, 0, 10, file1, file2, False)

# Create agent
device = torch.device("cpu")
agent = Agent(envs).to(device)
agent.load_state_dict(torch.load(
            "./Agents/agent_32767872steps.pt", map_location=device))

# Initialze variables
initErrors = []
finalErrors = []
maxDevs = []
maxForces = []
rewards = []
bestForces = []

# Select files
file2 ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
folder ='./AssemblyGym/envs/FuselageActuators/AnsysFiles/Test/'
files = os.listdir(folder)

# Loop over all files
for f in files[:-1]:
    file1 = path.join(folder, f)
    dp = file1[-8:-4] # Design point

    # Make the environment
    # env_name = "FuselageActuators-v22"
    # envs = gym.vector.SyncVectorEnv(
    #     [make_env(env_name, 0 + i, i, 10, file1, file2, False) for i in range(1)]
    # )

    envs = make_env(env_name, 0, 0, 10, file1, file2, False)

    print('*' * 30, f'File: {f}', '*' * 30)
    # Perform test and track error
    obs = torch.Tensor(envs.reset()).to(device)
    # initErrors.append(envs.error_initial)
    episodeReward = 0
    minError=10
    
    for j in range(10):
        with torch.no_grad():
            action, logprob, _, value = agent.get_action_and_value(obs, action = "deterministic")
        obs, reward, done, info = envs.step(action.cpu().numpy())
        obs = torch.Tensor(obs).to(device)
        episodeReward += reward
        # print("Intermediate Reward:", reward)
        print("Intermediate Error:", info["Error"])
        if info["Error"]<minError:
            minError= info["Error"]
            maxDev = info["maxDev"]
            maxForce = np.max(np.abs(info["Forces"]))
            bestForce = info["Forces"]
    print('_'*30)
    print("Best Error:", minError)
    initErrors.append(info["initError"])
    finalErrors.append(minError)
    maxForces.append(maxForce)
    maxDevs.append(maxDev)
    rewards.append(episodeReward)
    bestForces.append(bestForce)

    envs.close()

print("**********************************************************")
print("Initial error (mean) = %.4f" %np.mean(initErrors))
print("Initial error (median) = %.4f" %np.median(initErrors))
print("Initial error (stdev) = %.4f" %np.std(initErrors))
print("Initial error (max) = %.4f" %np.max(initErrors))
print("**********************************************************")
print("Final error (mean) = %.4f" %np.mean(finalErrors))
print("Final error (median) = %.4f" %np.median(finalErrors))
print("Final error (stdev) = %.4f" %np.std(finalErrors))
print("Final error (max) = %.4f" %np.max(finalErrors))
print("**********************************************************")
print("Max Deviation (mean) = %.4f" %np.mean(maxDevs))
print("Max Deviation (median) = %.4f" %np.median(maxDevs))
print("Max Deviation (stdev) = %.4f" %np.std(maxDevs))
print("Max Deviation (max) = %.4f" %np.max(maxDevs))
print("**********************************************************")
print("Max Force (mean) = %.4f" %np.mean(maxForces))
print("Max Force (median) = %.4f" %np.median(maxForces))
print("Max Force (stdev) = %.4f" %np.std(maxForces))
print("Max Force (max) = %.4f" %np.max(maxForces))
print("**********************************************************")
print("Best Forces:", bestForces)
# Out:
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\scooby\knowledge.py:14: DeprecationWarning: The distutils.sysconfig module is deprecated, use sysconfig instead
#   import distutils.sysconfig as sysconfig
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1072: DeprecationWarning: invalid escape sequence '\d'
#   and re.search("ansys\d\d\d", os.path.basename(os.path.normpath(exe_loc)))
# c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1249: DeprecationWarning: invalid escape sequence '\-'
#   """Start MAPDL locally.
# ---------------------------------------------------------------------------
#
# MapdlConnectionError                      Traceback (most recent call last)
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1851, in launch_mapdl(exec_file, run_location, jobname, nproc, ram, mode, override, loglevel, additional_switches, start_timeout, port, cleanup_on_exit, start_instance, ip, clear_on_connect, log_apdl, remove_temp_files, remove_temp_dir_on_exit, verbose_mapdl, license_server_check, license_type, print_com, add_env_vars, replace_env_vars, version, **kwargs)
#
#    1843 port, actual_run_location, process = launch_grpc(
#
#    1844     port=port,
#
#    1845     ip=ip,
#
#    (...)
#
#    1849     **start_parm,
#
#    1850 )
#
# -> 1851 mapdl = MapdlGrpc(
#
#    1852     ip=ip,
#
#    1853     port=port,
#
#    1854     cleanup_on_exit=cleanup_on_exit,
#
#    1855     loglevel=loglevel,
#
#    1856     set_no_abort=set_no_abort,
#
#    1857     remove_temp_dir_on_exit=remove_temp_dir_on_exit,
#
#    1858     log_apdl=log_apdl,
#
#    1859     process=process,
#
#    1860     **start_parm,
#
#    1861 )
#
#    1862 if run_location is None:
#
#
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:386, in MapdlGrpc.__init__(self, ip, port, timeout, loglevel, log_file, cleanup_on_exit, log_apdl, set_no_abort, remove_temp_files, remove_temp_dir_on_exit, print_com, channel, remote_instance, **start_parm)
#
#     385     self._post_mortem_checks()
#
# --> 386     raise err  # Raise original error if we couldn't catch it in post-mortem analysis
#
#     387 else:
#
#
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:383, in MapdlGrpc.__init__(self, ip, port, timeout, loglevel, log_file, cleanup_on_exit, log_apdl, set_no_abort, remove_temp_files, remove_temp_dir_on_exit, print_com, channel, remote_instance, **start_parm)
#
#     382 try:
#
# --> 383     self._multi_connect(timeout=timeout, set_no_abort=set_no_abort)
#
#     384 except MapdlConnectionError as err:
#
#
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:454, in MapdlGrpc._multi_connect(self, n_attempts, timeout, set_no_abort)
#
#     453 if not connected:
#
# --> 454     raise MapdlConnectionError(
#
#     455         f"Unable to connect to MAPDL gRPC instance at {self._channel_str}."
#
#     456     )
#
#     457 else:
#
#
#
# MapdlConnectionError: Unable to connect to MAPDL gRPC instance at 127.0.0.1:50052.
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# LicenseServerConnectionError              Traceback (most recent call last)
#
# File c:\Users\TL\Projects\Fuselage Actuator Reinforcement Learning\AssemblyGym\AssemblyGym\envs\FuselageActuators\FuselageActuators_env_v22.py:486, in FuselageActuatorsEnv._launch_ansys(self)
#
#     485 n_cpu = psutil.cpu_count(logical=False)
#
# --> 486 self.mapdl = launch_mapdl(loglevel='ERROR', verbose=False, nproc=n_cpu, cleanup_on_exit=True, override=True)
#
#     487 print(self.mapdl)
#
#
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1870, in launch_mapdl(exec_file, run_location, jobname, nproc, ram, mode, override, loglevel, additional_switches, start_timeout, port, cleanup_on_exit, start_instance, ip, clear_on_connect, log_apdl, remove_temp_files, remove_temp_dir_on_exit, verbose_mapdl, license_server_check, license_type, print_com, add_env_vars, replace_env_vars, version, **kwargs)
#
#    1869     LOG.debug("Checking license server.")
#
# -> 1870     lic_check.check()
#
#    1872 raise exception
#
#
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\licensing.py:160, in LicenseChecker.check(self)
#
#     159 elif self._license_file_success is False:
#
# --> 160     raise LicenseServerConnectionError("\n".join(self._license_file_msg))
#
#     162 if self._license_checkout_success:
#
#
#
# LicenseServerConnectionError: Exceeded timeout of 13 seconds while examining:
#
# C:\Users\TL\AppData\Local\Temp\.ansys\licdebug.FECONL24TS.FEAT_ANSYS.221.out
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# c:\Users\TL\Projects\Fuselage Actuator Reinforcement Learning\AssemblyGym\Benchmark.ipynb Cell 67 in <cell line: 69>()
#
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=63'>64</a> file1 ='C:/Users/TL/Projects/Fuselage Actuator Reinforcement Learning/AssemblyGym/AssemblyGym/envs/FuselageActuators/AnsysFiles/Benchmark/SolutionInputUndeformed.inp'
#
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=64'>65</a> # envs = gym.vector.SyncVectorEnv(
#
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=65'>66</a> #     [make_env(env_name, 0 + i, i, 10, file1, file2, False) for i in range(1)]
#
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=66'>67</a> # )
#
# ---> <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=68'>69</a> envs = make_env(env_name, 0, 0, 10, file1, file2, False)
#
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=70'>71</a> # Create agent
#
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=71'>72</a> device = torch.device("cpu")
#
#
#
# c:\Users\TL\Projects\Fuselage Actuator Reinforcement Learning\AssemblyGym\Benchmark.ipynb Cell 67 in make_env(env_id, seed, idx, n_actions, file1, file2, record)
#
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=13'>14</a> def make_env(env_id, seed, idx, n_actions, file1, file2, record):
#
# ---> <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=14'>15</a>     env = gym.make(env_id, n_actuators=n_actions, mode="Test", record=record, seed=seed)
#
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=15'>16</a>     #env = gym.wrappers.RecordEpisodeStatistics(env)
#
#      <a href='vscode-notebook-cell:/c%3A/Users/TL/Projects/Fuselage%20Actuator%20Reinforcement%20Learning/AssemblyGym/Benchmark.ipynb#Y124sZmlsZQ%3D%3D?line=16'>17</a>     return env
#
#
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\gym\envs\registration.py:649, in make(id, max_episode_steps, autoreset, new_step_api, disable_env_checker, **kwargs)
#
#     644         raise error.Error(
#
#     645             f"Invalid render_mode provided: {mode}. Valid render_modes: None, {', '.join(render_modes)}"
#
#     646         )
#
#     648 try:
#
# --> 649     env = env_creator(**_kwargs)
#
#     650 except TypeError as e:
#
#     651     if (
#
#     652         str(e).find("got an unexpected keyword argument 'render_mode'") >= 0
#
#     653         and apply_human_rendering
#
#     654     ):
#
#
#
# File c:\Users\TL\Projects\Fuselage Actuator Reinforcement Learning\AssemblyGym\AssemblyGym\envs\FuselageActuators\FuselageActuators_env_v22.py:76, in FuselageActuatorsEnv.__init__(self, render_mode, n_actuators, mode, port, file1, file2, record, seed)
#
#      73 if self.mode != 'Surrogate':
#
#      74     # Check if MAPDL server is active, and start it if it's not
#
#      75     if not self._monitor_process('ansys'):
#
# ---> 76         self._launch_ansys()
#
#      77 elif self.mode == 'Surrogate':
#
#      78     self.surrogate = load(path.join(path.dirname(__file__), 'Surrogates', 'surrogate_likeDu_v22.joblib') )
#
#
#
# File c:\Users\TL\Projects\Fuselage Actuator Reinforcement Learning\AssemblyGym\AssemblyGym\envs\FuselageActuators\FuselageActuators_env_v22.py:491, in FuselageActuatorsEnv._launch_ansys(self)
#
#     489 except:
#
#     490     n_cpu=min(4, n_cpu) #license sometimes won't let me use more than 4 processors?
#
# --> 491     self.mapdl = launch_mapdl(loglevel='ERROR', verbose=False, port=self.port, nproc=n_cpu, cleanup_on_exit=True, override=True)
#
#     492     print(self.mapdl)
#
#     493     print("Running on", n_cpu, "processors")
#
#
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\launcher.py:1851, in launch_mapdl(exec_file, run_location, jobname, nproc, ram, mode, override, loglevel, additional_switches, start_timeout, port, cleanup_on_exit, start_instance, ip, clear_on_connect, log_apdl, remove_temp_files, remove_temp_dir_on_exit, verbose_mapdl, license_server_check, license_type, print_com, add_env_vars, replace_env_vars, version, **kwargs)
#
#    1842 elif mode == "grpc":
#
#    1843     port, actual_run_location, process = launch_grpc(
#
#    1844         port=port,
#
#    1845         ip=ip,
#
#    (...)
#
#    1849         **start_parm,
#
#    1850     )
#
# -> 1851     mapdl = MapdlGrpc(
#
#    1852         ip=ip,
#
#    1853         port=port,
#
#    1854         cleanup_on_exit=cleanup_on_exit,
#
#    1855         loglevel=loglevel,
#
#    1856         set_no_abort=set_no_abort,
#
#    1857         remove_temp_dir_on_exit=remove_temp_dir_on_exit,
#
#    1858         log_apdl=log_apdl,
#
#    1859         process=process,
#
#    1860         **start_parm,
#
#    1861     )
#
#    1862     if run_location is None:
#
#    1863         mapdl._path = actual_run_location
#
#
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:383, in MapdlGrpc.__init__(self, ip, port, timeout, loglevel, log_file, cleanup_on_exit, log_apdl, set_no_abort, remove_temp_files, remove_temp_dir_on_exit, print_com, channel, remote_instance, **start_parm)
#
#     380     self._mapdl_process = process
#
#     382 try:
#
# --> 383     self._multi_connect(timeout=timeout, set_no_abort=set_no_abort)
#
#     384 except MapdlConnectionError as err:
#
#     385     self._post_mortem_checks()
#
#
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:439, in MapdlGrpc._multi_connect(self, n_attempts, timeout, set_no_abort)
#
#     437 while time.time() < max_time and i <= n_attempts:
#
#     438     self._log.debug("Connection attempt %d", i + 1)
#
# --> 439     connected = self._connect(
#
#     440         timeout=attempt_timeout, set_no_abort=set_no_abort
#
#     441     )
#
#     442     i += 1
#
#     443     if connected:
#
#
#
# File c:\Users\TL\Documents\PythonVENV\venv3_10-pyAnsys\lib\site-packages\ansys\mapdl\core\mapdl_grpc.py:641, in MapdlGrpc._connect(self, timeout, set_no_abort, enable_health_check)
#
#     639 tstart = time.time()
#
#     640 while ((time.time() - tstart) < timeout) and not self._state._matured:
#
# --> 641     time.sleep(0.01)
#
#     643 if not self._state._matured:  # pragma: no cover
#
#     644     return False
#
#
#
# KeyboardInterrupt:

# %% [markdown]
# Expected output
# **********************************************************
# Initial error (mean) = 0.467
# Initial error (median) = 0.482
# Initial error (stdev) = 0.251
# Initial error (max) = 0.923
# **********************************************************
# Final error (mean) = 0.010
# Final error (median) = 0.010
# Final error (stdev) = 0.003
# Final error (max) = 0.015
# **********************************************************
# Max Deviation (mean) = 0.034
# Max Deviation (median) = 0.035
# Max Deviation (stdev) = 0.009
# Max Deviation (max) = 0.056
# **********************************************************
# Max Force (mean) = 214.811
# Max Force (median) = 207.556
# Max Force (stdev) = 89.130
# Max Force (max) = 432.262
# **********************************************************
